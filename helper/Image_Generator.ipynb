# %%
import cv2 
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# %cd /gdrive/MyDrive/public_data/Dress/
# Out:
# /gdrive/MyDrive/public_data/Dress

# %%
# %ls
# Out:
# blank.jpg  east/  generated/  west/

# %%
blank = r'Input/blank.jpg'

apple_image_english = r'Input/apple_E.jpg'
apple_image_french  = r'Input/apple_F.jpg'
apple_image_hindi   = r'Input/apple_H.jpg'
apple_image_chinese = r'Input/apple_C.jpg'
apple_image_arabic  = r'Input/apple_A.jpg'

apple_text_english = r'Input/apple_english.jpg'
apple_text_french  = r'Input/apple_french.jpg'
apple_text_hindi   = r'Input/apple_hindi.jpg'
apple_text_chinese = r'Input/apple_chinese.jpg'
apple_text_arabic  = r'Input/apple_arabic.jpg'

sun_text_english = r'Input/sun_english.jpg'
sun_text_french  = r'Input/sun_french.jpg'
sun_text_hindi   = r'Input/sun_hindi.jpg'
sun_text_chinese = r'Input/sun_chinese.jpg'
sun_text_arabic  = r'Input/sun_arabic.jpg'

fish_text_english = r'Input/fish_english.jpg'
fish_text_french  = r'Input/fish_french.jpg'
fish_text_hindi   = r'Input/fish_hindi.jpg'
fish_text_chinese = r'Input/fish_chinese.jpg'
fish_text_arabic  = r'Input/fish_arabic.jpg'

mountain_text_english = r'Input/mountain_english.jpg'
mountain_text_french  = r'Input/mountain_french.jpg'
mountain_text_hindi   = r'Input/mountain_hindi.jpg'
mountain_text_chinese = r'Input/mountain_chinese.jpg'
mountain_text_arabic  = r'Input/mountain_arabic.jpg'

long_string_text_english = r'Input/long_string_english.jpg'
long_string_text_french  = r'Input/long_string_french.jpg'
long_string_text_hindi   = r'Input/long_string_hindi.jpg'
long_string_text_chinese = r'Input/long_string_chinese.jpg'
long_string_text_arabic  = r'Input/long_string_arabic.jpg'

long_string_text_english = r'Input/long_string_english.jpg'
long_string_text_gibberish  = r'Input/long_string_gibberish.jpg'
long_string_text_hindi   = r'Input/long_string_hindi.jpg'
long_string_text_chinese = r'Input/long_string_chinese.jpg'
long_string_text_arabic  = r'Input/long_string_arabic.jpg'

# %%
image1 = cv2.imread(apple_image_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(apple_image_arabic)
image4 = cv2.imread(apple_image_hindi)
image5 = cv2.imread(apple_image_chinese)
image6 = cv2.imread(apple_image_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/img_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/img_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/img_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/img_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/img_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/img_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/img_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/img_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/img_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/img_f_c.jpg', f_c)
# Out:
# True

# %%
image1 = cv2.imread(apple_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(apple_text_arabic)
image4 = cv2.imread(apple_text_hindi)
image5 = cv2.imread(apple_text_chinese)
image6 = cv2.imread(apple_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/apple_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/apple_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/apple_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/apple_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/apple_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/apple_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/apple_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/apple_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/apple_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/apple_f_c.jpg', f_c)

image1 = cv2.imread(mountain_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(mountain_text_arabic)
image4 = cv2.imread(mountain_text_hindi)
image5 = cv2.imread(mountain_text_chinese)
image6 = cv2.imread(mountain_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/mountain_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/mountain_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/mountain_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/mountain_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/mountain_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/mountain_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/mountain_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/mountain_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/mountain_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/mountain_f_c.jpg', f_c)

image1 = cv2.imread(sun_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(sun_text_arabic)
image4 = cv2.imread(sun_text_hindi)
image5 = cv2.imread(sun_text_chinese)
image6 = cv2.imread(sun_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/sun_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/sun_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/sun_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/sun_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/sun_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/sun_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/sun_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/sun_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/sun_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/sun_f_c.jpg', f_c)

image1 = cv2.imread(fish_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(fish_text_arabic)
image4 = cv2.imread(fish_text_hindi)
image5 = cv2.imread(fish_text_chinese)
image6 = cv2.imread(fish_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/fish_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/fish_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/fish_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/fish_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/fish_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/fish_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/fish_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/fish_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/fish_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/fish_f_c.jpg', f_c)

image1 = cv2.imread(long_string_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(long_string_text_arabic)
image4 = cv2.imread(long_string_text_hindi)
image5 = cv2.imread(long_string_text_chinese)
image6 = cv2.imread(long_string_text_gibberish)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/long_string_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/long_string_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/long_string_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/long_string_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/long_string_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/long_string_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/long_string_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/long_string_f_e.jpg', f_e)

c_g = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/long_string_c_g.jpg', c_g)

g_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/long_string_g_c.jpg', g_c)

    
import cv2 
from google.colab.patches import cv2_imshow

blank = r'Input/blank.jpg'

apple_image_english = r'Input/apple_E.jpg'
apple_image_french  = r'Input/apple_F.jpg'
apple_image_hindi   = r'Input/apple_H.jpg'
apple_image_chinese = r'Input/apple_C.jpg'
apple_image_arabic  = r'Input/apple_A.jpg'

apple_text_english = r'Input/apple_english.jpg'
apple_text_french  = r'Input/apple_french.jpg'
apple_text_hindi   = r'Input/apple_hindi.jpg'
apple_text_chinese = r'Input/apple_chinese.jpg'
apple_text_arabic  = r'Input/apple_arabic.jpg'

sun_text_english = r'Input/sun_english.jpg'
sun_text_french  = r'Input/sun_french.jpg'
sun_text_hindi   = r'Input/sun_hindi.jpg'
sun_text_chinese = r'Input/sun_chinese.jpg'
sun_text_arabic  = r'Input/sun_arabic.jpg'

fish_text_english = r'Input/fish_english.jpg'
fish_text_french  = r'Input/fish_french.jpg'
fish_text_hindi   = r'Input/fish_hindi.jpg'
fish_text_chinese = r'Input/fish_chinese.jpg'
fish_text_arabic  = r'Input/fish_arabic.jpg'

mountain_text_english = r'Input/mountain_english.jpg'
mountain_text_french  = r'Input/mountain_french.jpg'
mountain_text_hindi   = r'Input/mountain_hindi.jpg'
mountain_text_chinese = r'Input/mountain_chinese.jpg'
mountain_text_arabic  = r'Input/mountain_arabic.jpg'

long_string_text_english = r'Input/long_string_english.jpg'
long_string_text_french  = r'Input/long_string_french.jpg'
long_string_text_hindi   = r'Input/long_string_hindi.jpg'
long_string_text_chinese = r'Input/long_string_chinese.jpg'
long_string_text_arabic  = r'Input/long_string_arabic.jpg'

long_string_text_english = r'Input/long_string_english.jpg'
long_string_text_gibberish  = r'Input/long_string_gibberish.jpg'
long_string_text_hindi   = r'Input/long_string_hindi.jpg'
long_string_text_chinese = r'Input/long_string_chinese.jpg'
long_string_text_arabic  = r'Input/long_string_arabic.jpg'


image1 = cv2.imread(apple_image_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(apple_image_arabic)
image4 = cv2.imread(apple_image_hindi)
image5 = cv2.imread(apple_image_chinese)
image6 = cv2.imread(apple_image_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/img_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/img_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/img_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/img_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/img_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/img_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/img_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/img_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/img_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/img_f_c.jpg', f_c)

image1 = cv2.imread(apple_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(apple_text_arabic)
image4 = cv2.imread(apple_text_hindi)
image5 = cv2.imread(apple_text_chinese)
image6 = cv2.imread(apple_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/apple_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/apple_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/apple_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/apple_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/apple_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/apple_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/apple_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/apple_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/apple_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/apple_f_c.jpg', f_c)

image1 = cv2.imread(mountain_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(mountain_text_arabic)
image4 = cv2.imread(mountain_text_hindi)
image5 = cv2.imread(mountain_text_chinese)
image6 = cv2.imread(mountain_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/mountain_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/mountain_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/mountain_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/mountain_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/mountain_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/mountain_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/mountain_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/mountain_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/mountain_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/mountain_f_c.jpg', f_c)

image1 = cv2.imread(sun_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(sun_text_arabic)
image4 = cv2.imread(sun_text_hindi)
image5 = cv2.imread(sun_text_chinese)
image6 = cv2.imread(sun_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/sun_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/sun_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/sun_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/sun_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/sun_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/sun_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/sun_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/sun_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/sun_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/sun_f_c.jpg', f_c)

image1 = cv2.imread(fish_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(fish_text_arabic)
image4 = cv2.imread(fish_text_hindi)
image5 = cv2.imread(fish_text_chinese)
image6 = cv2.imread(fish_text_french)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/fish_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/fish_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/fish_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/fish_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/fish_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/fish_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/fish_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/fish_f_e.jpg', f_e)

c_f = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/fish_c_f.jpg', c_f)

f_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/fish_f_c.jpg', f_c)

image1 = cv2.imread(long_string_text_english)
image2 = cv2.imread(blank)
image3 = cv2.imread(long_string_text_arabic)
image4 = cv2.imread(long_string_text_hindi)
image5 = cv2.imread(long_string_text_chinese)
image6 = cv2.imread(long_string_text_gibberish)

e_a = cv2.hconcat([image1, image2, image3])
cv2.imwrite('Generated/long_string_e_a.jpg', e_a)

a_e = cv2.hconcat([image3, image2, image1])
cv2.imwrite('Generated/long_string_a_e.jpg', a_e)
 
e_h = cv2.hconcat([image1, image2, image4])
cv2.imwrite('Generated/long_string_e_h.jpg', e_h)

h_e = cv2.hconcat([image4, image2, image1])
cv2.imwrite('Generated/long_string_h_e.jpg', h_e)

e_c = cv2.hconcat([image1, image2, image5])
cv2.imwrite('Generated/long_string_e_c.jpg', e_c)

c_e = cv2.hconcat([image5, image2, image1])
cv2.imwrite('Generated/long_string_c_e.jpg', c_e)

e_f = cv2.hconcat([image1, image2, image6])
cv2.imwrite('Generated/long_string_e_f.jpg', e_f)

f_e = cv2.hconcat([image6, image2, image1])
cv2.imwrite('Generated/long_string_f_e.jpg', f_e)

c_g = cv2.hconcat([image5, image2, image6])
cv2.imwrite('Generated/long_string_c_g.jpg', c_g)

g_c = cv2.hconcat([image6, image2, image5])
cv2.imwrite('Generated/long_string_g_c.jpg', g_c)
# Out:
# True
